# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv("DataSet/Train.csv")
# Out:
# c:\users\chira\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (746,835) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#         Col1  Col2          Col3          Col4          Col5          Col6  \
# 0    RIGHGSN     1  1.086711e+04  8.648345e+03  1.576618e+04  2.890466e+04
# 1  RIMHI5ZGP     0  2.584312e+05  2.179633e+05  1.866287e+05  1.866287e+05
# 2  RIHOG1SZU     0  1.459355e+07  1.260060e+07  1.100315e+07  1.010315e+07
# 3  RIHOLMQWU     0  6.727043e+05  8.181116e+05  6.794893e+05  6.794893e+05
# 4  RIHO584ET     0 -1.218742e+06 -3.005361e+06 -1.666241e+05 -2.403574e+06
#
#            Col7          Col8          Col9         Col10  ...  Col2388  \
# 0  5.273655e+03  2.346153e+04  1.285597e+04  2.871509e+04  ...        0
# 1  2.154519e+05  1.923615e+05  1.726538e+05  1.666974e+05  ...        0
# 2  1.879882e+07  1.514035e+07  5.320778e+06  6.906324e+06  ...        0
# 3  8.257254e+05  7.605803e+05  3.577134e+05  4.236612e+05  ...        0
# 4  2.583183e+06  2.086546e+06  5.938358e+06  5.446532e+06  ...        0
#
#    Col2389  Col2390  Col2391  Col2392  Col2393  Col2394  Col2395  Col2396  \
# ...

# %%
target = data.Col2

# %%
DataDimension = 2395

# %%
DataTenCol = data.iloc[:,1:DataDimension+1]

# %%
colunsToBeDropped = []
for i, item in enumerate(DataTenCol.dtypes):
    if item.type not in [np.int64,np.float64]:
        colunsToBeDropped.append("Col"+str(i+2))
#         print(i+2)
#         print(item.type)

# %%
colunsToBeDropped
# Out:
# ['Col747', 'Col836']

# %%
# len(DataTenCol.Col836.isnull().values)

# %%
DataTenCol = DataTenCol.drop(colunsToBeDropped, axis=1)

# %%
DataTenCol.head()
# Out:
#    Col2          Col3          Col4          Col5          Col6          Col7  \
# 0     1  1.086711e+04  8.648345e+03  1.576618e+04  2.890466e+04  5.273655e+03
# 1     0  2.584312e+05  2.179633e+05  1.866287e+05  1.866287e+05  2.154519e+05
# 2     0  1.459355e+07  1.260060e+07  1.100315e+07  1.010315e+07  1.879882e+07
# 3     0  6.727043e+05  8.181116e+05  6.794893e+05  6.794893e+05  8.257254e+05
# 4     0 -1.218742e+06 -3.005361e+06 -1.666241e+05 -2.403574e+06  2.583183e+06
#
#            Col8          Col9         Col10         Col11  ...  Col2388  \
# 0  2.346153e+04  1.285597e+04  2.871509e+04  9.114586e+03  ...        0
# 1  1.923615e+05  1.726538e+05  1.666974e+05  2.013518e+05  ...        0
# 2  1.514035e+07  5.320778e+06  6.906324e+06  9.368338e+06  ...        0
# 3  7.605803e+05  3.577134e+05  4.236612e+05  4.304848e+05  ...        0
# 4  2.086546e+06  5.938358e+06  5.446532e+06  3.473444e+06  ...        0
#
# ...

# %%
DataTenCol.head()
# Out:
#    Col2          Col3          Col4          Col5          Col6          Col7  \
# 0     1  1.086711e+04  8.648345e+03  1.576618e+04  2.890466e+04  5.273655e+03
# 1     0  2.584312e+05  2.179633e+05  1.866287e+05  1.866287e+05  2.154519e+05
# 2     0  1.459355e+07  1.260060e+07  1.100315e+07  1.010315e+07  1.879882e+07
# 3     0  6.727043e+05  8.181116e+05  6.794893e+05  6.794893e+05  8.257254e+05
# 4     0 -1.218742e+06 -3.005361e+06 -1.666241e+05 -2.403574e+06  2.583183e+06
#
#            Col8          Col9         Col10         Col11  ...  Col2388  \
# 0  2.346153e+04  1.285597e+04  2.871509e+04  9.114586e+03  ...        0
# 1  1.923615e+05  1.726538e+05  1.666974e+05  2.013518e+05  ...        0
# 2  1.514035e+07  5.320778e+06  6.906324e+06  9.368338e+06  ...        0
# 3  7.605803e+05  3.577134e+05  4.236612e+05  4.304848e+05  ...        0
# 4  2.086546e+06  5.938358e+06  5.446532e+06  3.473444e+06  ...        0
#
# ...

# %%
DataTenCol.describe(include='all')
# Out:
#                Col2          Col3          Col4          Col5          Col6  \
# count  17521.000000  1.752100e+04  1.752100e+04  1.752100e+04  1.752100e+04
# mean       0.100508  3.158967e+04  2.046540e+04  2.502937e+04  2.789385e+04
# std        0.300685  7.612897e+05  7.136908e+05  6.018207e+05  6.091245e+05
# min        0.000000 -8.555719e+07 -8.555719e+07 -7.011955e+07 -7.100920e+07
# 25%        0.000000  2.742337e+03  2.007863e+03  1.857013e+03  2.562647e+03
# 50%        0.000000  9.308060e+03  6.642857e+03  6.236503e+03  8.464355e+03
# 75%        0.000000  3.053873e+04  2.156093e+04  2.068154e+04  2.773849e+04
# max        1.000000  1.459355e+07  1.288980e+07  1.478068e+07  1.178075e+07
#
#                Col7          Col8          Col9         Col10         Col11  \
# count  1.752100e+04  1.752100e+04  1.752100e+04  1.752100e+04  1.752100e+04
# mean   2.597734e+04  3.302600e+04  2.912693e+04  2.971069e+04  3.617392e+04
# ...

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(fill_value = 0, missing_values = np.NaN)

# %%
y = DataTenCol.iloc[:,0]

# %%
important_features = ['Col177',
 'Col877',
 'Col875',
 'Col18',
 'Col874',
 'Col636',
 'Col681',
 'Col586',
 'Col106',
 'Col915',
 'Col37',
 'Col933',
 'Col876',
 'Col26',
 'Col166',
 'Col614',
 'Col243',
 'Col163',
 'Col444',
 'Col179',
 'Col173',
 'Col872',
 'Col914',
 'Col519',
 'Col725',
 'Col21',
 'Col907',
 'Col175',
 'Col889',
 'Col13',
 'Col621',
 'Col603',
 'Col814',
 'Col246',
 'Col162',
 'Col579',
 'Col390',
 'Col912',
 'Col172',
 'Col257',
 'Col652',
 'Col633',
 'Col443',
 'Col24',
 'Col174',
 'Col25',
 'Col240',
 'Col167',
 'Col885',
 'Col9']

# %%
X = DataTenCol[important_features].copy()

# %%
input_dim = X.shape[1]

# %%
# X = DataTenCol.iloc[:,1:]

# %%
X.isnull().values.any()
# Out:
# True

# %%
X = pd.DataFrame(imp.fit_transform(X.values),index = X.index, columns = X.columns)

# %%
X.isnull().values.any()
# Out:
# False

# %%
# sns.pairplot(DataTenCol,hue='Col2')

# %%
X.head()
# Out:
#      Col177    Col877    Col875     Col18    Col874    Col636    Col681  \
# 0  0.983505  1.160181  4.015786  0.403366  4.015786  0.460104 -0.382431
# 1  0.893896  1.070587  2.984058  2.676398  2.984058  0.000000  0.454620
# 2  0.861632  0.258884  2.271018  2.203874  2.271018  0.002855  0.529382
# 3  0.976665  1.070587  3.065040  0.536304  3.065040  0.000000  0.567619
# 4  0.988593  0.578306  3.598077  3.487721  3.598077  2.520248  0.476344
#
#      Col586     Col106    Col915  ...  Col652    Col633    Col443     Col24  \
# 0  0.333333  17.980863  1.048415  ...  0.0000  0.000000  0.582386  1.297050
# 1  0.000000   0.957537  0.000000  ...  0.0000  0.000000  1.836166  0.966620
# 2  1.666667   0.482401  1.000000  ...  0.0020  0.000068  0.641678  0.735339
# 3  0.000000   0.223275  2.000000  ...  0.0125  0.001353  0.973267  0.534531
# 4  6.000000  -0.479454  0.000000  ...  0.9049  0.010466  0.782257  1.563430
#
#      Col174     Col25    Col240    Col167    Col885          Col9
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
updatedX = sc.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
XTrain,XTest,YTrain,YTest = train_test_split(updatedX,y,test_size=0.001)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
import time
def base_model():
    model = Sequential()
    model.add(Dense(640, input_dim=input_dim, kernel_initializer='normal', activation='relu'))
    model.add(Dense(626, kernel_initializer='normal', activation='relu'))
    model.add(Dense(580, kernel_initializer='normal', activation='relu'))
    model.add(Dense(546, kernel_initializer='normal', activation='tanh'))
    model.add(Dense(510, kernel_initializer='normal', activation='relu'))
    model.add(Dense(486, kernel_initializer='normal', activation='relu'))
    model.add(Flatten())
    model.add(Dropout(0.2))
    model.add(Dense(426, kernel_initializer='normal', activation='relu'))
    model.add(Dense(380, kernel_initializer='normal', activation='tanh'))
    model.add(Dense(346, kernel_initializer='normal', activation='relu'))
    model.add(Dense(310, kernel_initializer='normal', activation='tanh'))
    model.add(Dense(286, kernel_initializer='normal', activation='relu'))
    model.add(Flatten())
    model.add(Dropout(0.2))
    model.add(Dense(270, kernel_initializer='normal', activation='relu'))
    model.add(Dense(264, kernel_initializer='normal', activation='tanh'))
    model.add(Dense(260, kernel_initializer='normal', activation='relu'))
    model.add(Dense(254, kernel_initializer='normal', activation='tanh'))
    model.add(Dense(245, kernel_initializer='normal', activation='relu'))
    model.add(Dense(220, kernel_initializer='normal', activation='relu'))
    model.add(Flatten())
    model.add(Dropout(0.2))
    model.add(Dense(196, kernel_initializer='normal', activation='relu'))
    model.add(Dense(180, kernel_initializer='normal', activation='relu'))
    model.add(Dense(146, kernel_initializer='normal', activation='relu'))
    model.add(Dense(110, kernel_initializer='normal', activation='relu'))
    model.add(Dense(86, kernel_initializer='normal', activation='relu'))
    model.add(Flatten())
    model.add(Dropout(0.2))
    model.add(Dense(86, kernel_initializer='normal', activation='relu'))
    model.add(Dense(73, kernel_initializer='normal', activation='relu'))
    model.add(Dense(56, kernel_initializer='normal', activation='relu'))
    model.add(Dense(40, kernel_initializer='normal', activation='relu'))
    model.add(Dense(16, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal',activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])
    return model

# %%
model1 = base_model()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0928 17:58:57.602894  1796 deprecation.py:506] From c:\users\chira\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\initializers.py:143: calling RandomNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0928 17:58:58.337928  1796 deprecation.py:323] From c:\users\chira\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
model1.fit(XTrain,YTrain, batch_size=40,epochs=150)
# Out:
# Epoch 1/150
# 17503/17503 [==============================] - 14s 796us/sample - loss: 0.3701 - acc: 0.8994
# Epoch 2/150
# 17503/17503 [==============================] - 20s 1ms/sample - loss: 0.3358 - acc: 0.89940s - loss: 0.3373 -
# Epoch 3/150
# 17503/17503 [==============================] - 20s 1ms/sample - loss: 0.3326 - acc: 0.89945s - los
# Epoch 4/150
# 17503/17503 [==============================] - 21s 1ms/sample - loss: 0.3286 - acc: 0.8994
# Epoch 5/150
# 17503/17503 [==============================] - 21s 1ms/sample - loss: 0.3273 - acc: 0.89940s - loss: 0.3273 - acc: 0.899
# Epoch 6/150
# 17503/17503 [==============================] - 20s 1ms/sample - loss: 0.3278 - acc: 0.89940s - loss: 0.3279 - acc: 0.8
# Epoch 7/150
# 17503/17503 [==============================] - 21s 1ms/sample - loss: 0.3273 - acc: 0.899410s - loss: 0.3228 - acc: - ETA: 9s - loss: 0.3240 - acc: 0 - ETA: 9s - loss: 0.3245 - acc: 0.9 -  - ETA: 2s - los
# Epoch 8/150
# ...

# %%
evaluation = model1.evaluate(XTrain,YTrain)

# %%
evaluation = model1.evaluate(XTest,YTest)

# %%
ypred = (model1.predict(XTest)>0.5)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ypred,YTest)*100

# %%
dataTest = pd.read_csv("DataSet/Test.csv")

# %%
dataTest.head()

# %%
# TestData = dataTest.iloc[:,1:DataDimension]

# %%
TestData = dataTest[important_features].copy()

# %%
TestData = TestData.drop(colunsToBeDropped, axis=1)

# %%
TestData.head()

# %%
TestData.isnull().values.any()

# %%
np.all(X.columns == TestData.columns)

# %%
convert_dict = {}
for i, item in enumerate(TestData.dtypes):
    if item.type not in [np.int64,np.float64]:
        convert_dict['Col'+str(i+3)] = np.float64
#         print(i+3)
#         print(item.type)

# %%
TestData = TestData.replace('-',np.NaN).astype(convert_dict)

# %%
TestData = pd.DataFrame(sc.transform(imp.transform(TestData.values)),index = TestData.index, columns = TestData.columns)

# %%
TestData.isnull().values.any()

# %%
TestData.head()

# %%
out = [int(item[0]) for item in model1.predict(TestData)]

# %%
outputDataFrameContents = {'Col1': dataTest.Col1.to_list(),'Col2':out}
outputDataFrame = pd.DataFrame(outputDataFrameContents)

# %%
outputDataFrame.head()

# %%
outfilename = "Output\Prediction{}.csv".format(int(time.time()))
outputDataFrame.to_csv(outfilename, index=False)
